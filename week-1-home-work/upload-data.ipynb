# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
df = pd.read_csv('green_tripdata_2019-01.csv')
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# 2                       N           1            49           189
# 3                       N           1           189            17
# 4                       N           1            82           258
# ...                   ...         ...           ...           ...
# 630913                  N           1           255           226
# 630914                  N           1            75           151
# 630915                  N           1            75           238
# 630916                  N           1            74            74
# 630917                  N           1            75           262
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                     5           0.00          3.0    0.5      0.5
# 1                     2           0.86          6.0    0.5      0.5
# 2                     2           0.66          4.5    0.5      0.5
# 3                     2           2.68         13.5    0.5      0.5
# 4                     1           4.53         18.0    0.5      0.5
# ...                 ...            ...          ...    ...      ...
# 630913                1           3.33         13.0    0.5      0.5
# 630914                1           0.72          4.0    0.5      0.5
# 630915                1           1.75          7.0    0.5      0.5
# 630916                1           0.57          5.0    0.5      0.5
# 630917                1           2.11          8.5    0.5      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             0.00           0.0        NaN                    0.3
# 1             0.00           0.0        NaN                    0.3
# 2             0.00           0.0        NaN                    0.3
# 3             2.96           0.0        NaN                    0.3
# 4             0.00           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 630913        2.14           0.0        NaN                    0.3
# 630914        1.06           0.0        NaN                    0.3
# 630915        0.00           0.0        NaN                    0.3
# 630916        1.00           0.0        NaN                    0.3
# 630917        1.96           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0               4.30             2          1                   NaN
# 1               7.30             2          1                   NaN
# 2               5.80             1          1                   NaN
# 3              19.71             1          1                   NaN
# 4              19.30             2          1                   NaN
# ...              ...           ...        ...                   ...
# 630913         18.39             1          1                   0.0
# 630914          6.36             1          1                   0.0
# 630915          8.30             1          1                   0.0
# 630916          7.30             1          1                   0.0
# 630917         11.76             1          1                   0.0
#
# [630918 rows x 20 columns]

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5433/green_ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0               1           264           264                5           0.00
# 1               1            97            49                2           0.86
# 2               1            49           189                2           0.66
# 3               1           189            17                2           2.68
# 4               1            82           258                1           4.53
# ...           ...           ...           ...              ...            ...
# 99995           1           130           216                1           1.23
# 99996           5           218            16                1          21.44
# 99997           5           139           188                1          14.77
# 99998           1            72           188                1           1.80
# 99999           5            89           225                1           7.03
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0             3.00    0.5      0.5        0.00          0.00        NaN
# 1             6.00    0.5      0.5        0.00          0.00        NaN
# 2             4.50    0.5      0.5        0.00          0.00        NaN
# 3            13.50    0.5      0.5        2.96          0.00        NaN
# 4            18.00    0.5      0.5        0.00          0.00        NaN
# ...            ...    ...      ...         ...           ...        ...
# 99995         6.00    0.0      0.5        0.00          0.00        NaN
# 99996        47.65    0.0      0.5        0.00          5.76        NaN
# 99997        37.84    0.0      0.5        0.00          0.00        NaN
# 99998         8.50    0.0      0.5        0.00          0.00        NaN
# 99999        23.14    0.0      0.5        0.00          0.00        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                        0.3          4.30             2          1
# 1                        0.3          7.30             2          1
# 2                        0.3          5.80             1          1
# 3                        0.3         19.71             1          1
# 4                        0.3         19.30             2          1
# ...                      ...           ...           ...        ...
# 99995                    0.3          6.80             2          1
# 99996                    0.0         53.91             1          2
# 99997                    0.0         38.34             1          2
# 99998                    0.3          9.30             1          1
# 99999                    0.0         23.64             1          2
#
#        congestion_surcharge
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 99995                   NaN
# 99996                   NaN
# 99997                   NaN
# 99998                   NaN
# 99999                   NaN
#
# [100000 rows x 20 columns]

# %%
df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')

# %%
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 6.46 s, sys: 476 ms, total: 6.94 s
# Wall time: 22.2 s

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 23.514 second
# inserted another chunk, took 21.306 second
# inserted another chunk, took 21.049 second
# inserted another chunk, took 25.542 second
# inserted another chunk, took 21.123 second
# inserted another chunk, took 6.901 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-38-d8e114972b3d> in <module>
#       2     t_start = time()
#       3
# ----> 4     df = next(df_iter)
#       5
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __next__(self)
#    1032     def __next__(self):
#    1033         try:
# -> 1034             return self.get_chunk()
#    1035         except StopIteration:
#    1036             self.close()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1082                 raise StopIteration
#    1083             size = min(size, self.nrows - self._currow)
# -> 1084         return self.read(nrows=size)
#    1085
#    1086     def __enter__(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# StopIteration:

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2023-01-23 15:22:56--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.173.168, 54.231.201.88, 52.216.209.152, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.173.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12322 (12K) [application/octet-stream]
# Saving to: ‘taxi+_zone_lookup.csv’
#
# taxi+_zone_lookup.c 100%[===================>]  12.03K  --.-KB/s    in 0s
#
# 2023-01-23 15:22:57 (41.7 MB/s) - ‘taxi+_zone_lookup.csv’ saved [12322/12322]

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
